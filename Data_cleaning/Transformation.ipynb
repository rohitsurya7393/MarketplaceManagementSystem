# %%
import pandas as pd


Dataset = pd.read_csv('Dataset.csv',  encoding='latin1')


Dataset.head()
# Out:
# /var/folders/b0/kmv3xkq15d348v9hg51y4r9h0000gn/T/ipykernel_15645/1977156003.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
Dataset['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
# Adding a column shipping charge and add values to that column based on the shipping mode
Dataset['Shipping Charge'] = None

for index , rows in Dataset.iterrows():
    if rows['Ship Mode'] == 'Standard Class':
        Dataset.at[index, 'Shipping Charge'] = 10
    elif rows['Ship Mode'] == 'Second Class':
        Dataset.at[index, 'Shipping Charge'] = 15

    elif rows['Ship Mode'] == 'First Class':
        Dataset.at[index, 'Shipping Charge'] = 20

    elif rows['Ship Mode'] == 'Same Day':
        Dataset.at[index, 'Shipping Charge'] = 30

# %%
# Adding a column shipping description to the dataaset and fill in values based on shipping mode
Dataset['Shipping Description'] = None

for index , rows in Dataset.iterrows():
    if rows['Ship Mode'] == 'Standard Class':
        Dataset.at[index, 'Shipping Description'] = 'Shipping within 10 Days'
    elif rows['Ship Mode'] == 'Second Class':
        Dataset.at[index, 'Shipping Description'] = 'Shipping within a week'

    elif rows['Ship Mode'] == 'First Class':
        Dataset.at[index, 'Shipping Description'] = 'Shipping within 2 days'

    elif rows['Ship Mode'] == 'Same Day':
        Dataset.at[index, 'Shipping Description'] = 'Delivery on Same Day'

# %%
Dataset.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System   22.3680        2
#
#   Discount    Profit  Shipping Charge     Shipping Description
# 0     0.00   41.9136               15   Shipping within a week
# 1     0.00  219.5820               15   Shipping within a week
# 2     0.00    6.8714               15   Shipping within a week
# 3     0.45 -383.0310               10  Shipping within 10 Days
# 4     0.20    2.5164               10  Shipping within 10 Days
#
# [5 rows x 23 columns]

# %%
# Price per Item
# Adding temporary price per item into the dataset
Dataset['Price_per_item'] = None

Dataset['Price_per_item']  = Dataset['Sales'] / Dataset['Quantity']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Price per Item
# ----> 2 Dataset['Price_per_item'] = None
#       4 Dataset['Price_per_item']  = Dataset['Sales'] / Dataset['Quantity']
#
# NameError: name 'Dataset' is not defined

# %%
Dataset.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# 2  Office Supplies        Labels
# 3        Furniture        Tables
# 4  Office Supplies       Storage
#
#                                         Product Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System   22.3680        2
#
#   Discount    Profit  Shipping Charge     Shipping Description  Price_per_item
# 0     0.00   41.9136               15   Shipping within a week        130.9800
# 1     0.00  219.5820               15   Shipping within a week        243.9800
# 2     0.00    6.8714               15   Shipping within a week          7.3100
# 3     0.45 -383.0310               10  Shipping within 10 Days        191.5155
# 4     0.20    2.5164               10  Shipping within 10 Days         11.1840
#
# [5 rows x 24 columns]

# %%
# Dropping Unnecessary Columns
Dataset.drop('Sales', axis=1, inplace=True)
Dataset.drop('Discount', axis=1, inplace=True)
Dataset.drop('Profit', axis=1, inplace=True)

# %%
Dataset['Segment'].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
# Adding new column Profit Percent and filling in values based on customer segment
Dataset['Profit_percent'] = None

for index , rows in Dataset.iterrows():
    if rows['Segment'] == 'Consumer':
        Dataset.at[index, 'Profit_percent'] = 20
    elif rows['Segment'] == 'Corporate':
        Dataset.at[index, 'Profit_percent'] = 10

    elif rows['Segment'] == 'Home Office':
        Dataset.at[index, 'Profit_percent'] = 5

# %%
Dataset.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name Quantity Shipping Charge  \
# 0                  Bush Somerset Collection Bookcase        2              15
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...        3              15
# 2  Self-Adhesive Address Labels for Typewriters b...        2              15
# 3      Bretford CR4500 Series Slim Rectangular Table        5              10
# 4                     Eldon Fold 'N Roll Cart System        2              10
#
#       Shipping Description Price_per_item Profit_percent
# 0   Shipping within a week       130.9800             20
# 1   Shipping within a week       243.9800             20
# 2   Shipping within a week         7.3100             10
# 3  Shipping within 10 Days       191.5155             20
# 4  Shipping within 10 Days        11.1840             20
#
# [5 rows x 22 columns]

# %%
# Filling in temporary values to Total_Cost_Price Total_Sale_price Final_Price
Dataset['Total_Cost_Price'] = None
Dataset['Total_Sale_price'] = None

# %%
Dataset['Total_Cost_Price'] = (Dataset['Price_per_item'] * Dataset['Quantity'])

# %%
Dataset['Total_Sale_price'] = Dataset['Total_Cost_Price'] + (Dataset['Total_Cost_Price'] * (Dataset['Profit_percent'] / 100))

# %%
Dataset['Final_Price'] = Dataset['Total_Sale_price'] + Dataset['Shipping Charge']

# %%
Dataset.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Sub-Category                                       Product Name Quantity  \
# 0    Bookcases                  Bush Somerset Collection Bookcase        2
# 1       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...        3
# 2       Labels  Self-Adhesive Address Labels for Typewriters b...        2
# 3       Tables      Bretford CR4500 Series Slim Rectangular Table        5
# 4      Storage                     Eldon Fold 'N Roll Cart System        2
#
#   Shipping Charge     Shipping Description Price_per_item Profit_percent  \
# 0              15   Shipping within a week       130.9800             20
# 1              15   Shipping within a week       243.9800             20
# 2              15   Shipping within a week         7.3100             10
# 3              10  Shipping within 10 Days       191.5155             20
# 4              10  Shipping within 10 Days        11.1840             20
#
#    Total_Cost_Price Total_Sale_price Final_Price
# 0          261.9600          314.352     329.352
# 1          731.9400          878.328     893.328
# 2           14.6200           16.082      31.082
# 3          957.5775         1149.093    1159.093
# 4           22.3680          26.8416     36.8416
#
# [5 rows x 25 columns]

# %%
Dataset.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Sub-Category                                       Product Name Quantity  \
# 0    Bookcases                  Bush Somerset Collection Bookcase        2
# 1       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...        3
# 2       Labels  Self-Adhesive Address Labels for Typewriters b...        2
# 3       Tables      Bretford CR4500 Series Slim Rectangular Table        5
# 4      Storage                     Eldon Fold 'N Roll Cart System        2
#
#   Shipping Charge     Shipping Description Price_per_item Profit_percent  \
# 0              15   Shipping within a week       130.9800             20
# 1              15   Shipping within a week       243.9800             20
# 2              15   Shipping within a week         7.3100             10
# 3              10  Shipping within 10 Days       191.5155             20
# 4              10  Shipping within 10 Days        11.1840             20
#
#    Total_Cost_Price Total_Sale_price Final_Price
# 0          261.9600          314.352     329.352
# 1          731.9400          878.328     893.328
# 2           14.6200           16.082      31.082
# 3          957.5775         1149.093    1159.093
# 4           22.3680          26.8416     36.8416
#
# [5 rows x 25 columns]

# %%
# Saving the dataset in utf-8 encoding
Dataset.to_csv('output.csv', encoding='utf-8', index=False)
